# %%
import pandas as pd

# %%
import sweetviz

# %%
train = pd.read_csv('C:/Users/vikas/Downloads/house-prices-advanced-regression-techniques/train.csv')

# %%
test = pd.read_csv('C:/Users/vikas/Downloads/house-prices-advanced-regression-techniques/test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
report = sweetviz.analyze([train,"Train"],target_feat='SalePrice')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# :TARGET::                          |▎                    | [  1%]   00:00  -> (00:05 left)
# :TARGET::                          |▌                    | [  2%]   00:01  -> (01:10 left)
# :Id:                               |▌                    | [  2%]   00:01  -> (01:10 left)
# :Id:                               |▊                    | [  4%]   00:02  -> (01:15 left)
# :MSSubClass:                       |▊                    | [  4%]   00:02  -> (01:15 left)
# :MSSubClass:                       |█                    | [  5%]   00:03  -> (01:13 left)
# :MSZoning:                         |█                    | [  5%]   00:03  -> (01:13 left)
# :MSZoning:                         |█▎                   | [  6%]   00:04  -> (01:09 left)
# ...

# %%
report.show_html('Report.html')

# %%
compare_report = sweetviz.compare([train,'train'],[test,'test'],'SalePrice')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
# Summarizing dataframe:             |▎                    | [  1%]   00:00  -> (00:11 left)
# :TARGET::                          |▎                    | [  1%]   00:00  -> (00:11 left)
# :TARGET::                          |▌                    | [  2%]   00:00  -> (00:24 left)
# :Id:                               |▌                    | [  2%]   00:00  -> (00:24 left)
# :Id:                               |▊                    | [  4%]   00:02  -> (00:45 left)
# :MSSubClass:                       |▊                    | [  4%]   00:02  -> (00:45 left)
# :MSSubClass:                       |█                    | [  5%]   00:03  -> (00:56 left)
# :MSZoning:                         |█                    | [  5%]   00:03  -> (00:56 left)
# ...

# %%
compare_report.show_html('Report.html')
